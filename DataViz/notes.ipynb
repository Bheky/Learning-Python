# %% [markdown]
# ## Data Viz
#
#
# ### Defining Custom Colors
#     - to change the color of points, we pass the argument `color` to `scatter()` with the name of a color to use in quotation marks.

# %%
import matplotlib.pyplot as plt

# %%
ax.scatter(x_values, y_values, color='red', s=10)

# We can define custom colors using the RGB color model
ax.scatter(x_values, y_values, color=(0, 0.8, 0), s=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ax.scatter(x_values, y_values, color='red', s=10)
#
# NameError: name 'ax' is not defined

# %% [markdown]
# * colormaps are used to emphasize patterns in data as it ensures all points in the visualisation vary smoothly and accurately along a well-designed color scale.

# %%
# plt.savefig to save the plot to a file.
plt.savefig('sqaures_plot.png', bbox_inches='tight')

# %% [markdown]
# ### Random Walks
#
# * random walk = is a path that is determined by a series of simple decisions, each of which is left entirely to chance.

# %%
# subplots() call can be used to adjust the size of Matplotlib's output.
fig, ax = plt.subplots(figsize(15, 9))
