# %% [markdown]
# ## Application Programming Interface (API)
#
#     * an API is part of a website designed to interact with programs. these programs use very specific URL to request (API call) certain information.
